# %% [markdown]
# # working with html link

# %%
import pandas as pd

# %%
df=pd.read_html("https://www.baseball-reference.com/leagues/NL/bat.shtml")
df
# Out:
# [     Year Tms #Bat BatAge   R/G     G     PA     AB     R      H  ...   OBP  \
#  0    2022  15  426   28.5  4.34  2430  37.61  33.60  4.34   8.16  ...  .314
#  1    2021  15  815   28.7  4.46  2428  37.46  33.20  4.46   8.04  ...  .318
#  2    2020  15  327   28.4  4.71   898  36.97  32.74  4.71   8.07  ...  .325
#  3    2019  15  727   28.2  4.78  2430  38.37  34.20  4.78   8.59  ...  .323
#  4    2018  15  730   27.9  4.37  2432  38.19  34.01  4.37   8.39  ...  .318
#  ..    ...  ..  ...    ...   ...   ...    ...    ...   ...    ...  ...   ...
#  147  1880   8  127   24.8  4.69   680  36.83  35.74  4.69   8.74  ...  .267
#  148  1879   8  119   24.7  5.31   642  38.42  37.62  5.31   9.61  ...  .271
#  149  1878   6   77   24.7  5.17   368  38.07  37.08  5.17   9.62  ...  .279
#  150  1877   6   92   25.9  5.67   360  38.92  37.96  5.67  10.29  ...  .289
#  151  1876   8  121   25.3  5.90   520  39.34  38.69  5.90  10.27  ...  .277
#
# ...

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [     Year Tms #Bat BatAge   R/G     G     PA     AB     R      H  ...   OBP  \
#  0    2022  15  426   28.5  4.34  2430  37.61  33.60  4.34   8.16  ...  .314
#  1    2021  15  815   28.7  4.46  2428  37.46  33.20  4.46   8.04  ...  .318
#  2    2020  15  327   28.4  4.71   898  36.97  32.74  4.71   8.07  ...  .325
#  3    2019  15  727   28.2  4.78  2430  38.37  34.20  4.78   8.59  ...  .323
#  4    2018  15  730   27.9  4.37  2432  38.19  34.01  4.37   8.39  ...  .318
#  ..    ...  ..  ...    ...   ...   ...    ...    ...   ...    ...  ...   ...
#  147  1880   8  127   24.8  4.69   680  36.83  35.74  4.69   8.74  ...  .267
#  148  1879   8  119   24.7  5.31   642  38.42  37.62  5.31   9.61  ...  .271
#  149  1878   6   77   24.7  5.17   368  38.07  37.08  5.17   9.62  ...  .279
#  150  1877   6   92   25.9  5.67   360  38.92  37.96  5.67  10.29  ...  .289
#  151  1876   8  121   25.3  5.90   520  39.34  38.69  5.90  10.27  ...  .277
#
# ...

# %%
len(df)
# Out:
# 2

# %%
df[0]
# Out:
#      Year Tms #Bat BatAge   R/G     G     PA     AB     R      H  ...   OBP  \
# 0    2022  15  426   28.5  4.34  2430  37.61  33.60  4.34   8.16  ...  .314
# 1    2021  15  815   28.7  4.46  2428  37.46  33.20  4.46   8.04  ...  .318
# 2    2020  15  327   28.4  4.71   898  36.97  32.74  4.71   8.07  ...  .325
# 3    2019  15  727   28.2  4.78  2430  38.37  34.20  4.78   8.59  ...  .323
# 4    2018  15  730   27.9  4.37  2432  38.19  34.01  4.37   8.39  ...  .318
# ..    ...  ..  ...    ...   ...   ...    ...    ...   ...    ...  ...   ...
# 147  1880   8  127   24.8  4.69   680  36.83  35.74  4.69   8.74  ...  .267
# 148  1879   8  119   24.7  5.31   642  38.42  37.62  5.31   9.61  ...  .271
# 149  1878   6   77   24.7  5.17   368  38.07  37.08  5.17   9.62  ...  .279
# 150  1877   6   92   25.9  5.67   360  38.92  37.96  5.67  10.29  ...  .289
# 151  1876   8  121   25.3  5.90   520  39.34  38.69  5.90  10.27  ...  .277
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=pd.read_html('https://www.baseball-reference.com/leagues/NL/2014-standard-batting.shtml')
df1
# Out:
# [                       Tm  #Bat  BatAge   R/G     G     PA     AB     R  \
#  0    Arizona Diamondbacks    52    27.6  3.80   162   6089   5552   615
#  1          Atlanta Braves    39    26.8  3.54   162   6064   5468   573
#  2            Chicago Cubs    48    26.8  3.79   162   6102   5508   614
#  3         Cincinnati Reds    45    29.0  3.67   162   5978   5395   595
#  4        Colorado Rockies    49    27.3  4.66   162   6164   5612   755
#  5     Los Angeles Dodgers    49    29.4  4.43   162   6231   5560   718
#  6           Miami Marlins    45    27.4  3.98   162   6185   5538   645
#  7       Milwaukee Brewers    40    28.8  4.01   162   6065   5462   650
#  8           New York Mets    45    28.4  3.88   162   6145   5472   629
#  9   Philadelphia Phillies    49    30.7  3.82   162   6198   5603   619
#  10     Pittsburgh Pirates    45    27.3  4.21   162   6224   5536   682
#  11       San Diego Padres    51    27.9  3.30   162   5905   5294   535
# ...

# %%
df2=pd.read_html('https://www.baseball-reference.com/leagues/majors/2014.shtml#teams_standard_batting')
df2
# Out:
# [                               Tm  #Bat  BatAge   R/G     G      PA      AB  \
#  0            Arizona Diamondbacks    52    27.6  3.80   162    6089    5552
#  1                  Atlanta Braves    39    26.8  3.54   162    6064    5468
#  2               Baltimore Orioles    44    28.3  4.35   162    6130    5596
#  3                  Boston Red Sox    55    29.1  3.91   162    6226    5551
#  4                    Chicago Cubs    48    26.8  3.79   162    6102    5508
#  5               Chicago White Sox    44    27.7  4.07   162    6077    5543
#  6                 Cincinnati Reds    45    29.0  3.67   162    5978    5395
#  7               Cleveland Indians    46    28.6  4.13   162    6222    5575
#  8                Colorado Rockies    49    27.3  4.66   162    6164    5612
#  9                  Detroit Tigers    48    29.8  4.67   162    6202    5630
#  10                 Houston Astros    48    25.4  3.88   162    6055    5447
# ...

# %%
len(df2)
# Out:
# 1

# %%
df2[0]
# Out:
#                                Tm  #Bat  BatAge   R/G     G      PA      AB  \
# 0            Arizona Diamondbacks    52    27.6  3.80   162    6089    5552
# 1                  Atlanta Braves    39    26.8  3.54   162    6064    5468
# 2               Baltimore Orioles    44    28.3  4.35   162    6130    5596
# 3                  Boston Red Sox    55    29.1  3.91   162    6226    5551
# 4                    Chicago Cubs    48    26.8  3.79   162    6102    5508
# 5               Chicago White Sox    44    27.7  4.07   162    6077    5543
# 6                 Cincinnati Reds    45    29.0  3.67   162    5978    5395
# 7               Cleveland Indians    46    28.6  4.13   162    6222    5575
# 8                Colorado Rockies    49    27.3  4.66   162    6164    5612
# 9                  Detroit Tigers    48    29.8  4.67   162    6202    5630
# 10                 Houston Astros    48    25.4  3.88   162    6055    5447
# ...

# %%
df[0]
# Out:
#      Year Tms #Bat BatAge   R/G     G     PA     AB     R      H  ...   OBP  \
# 0    2022  15  426   28.5  4.34  2430  37.61  33.60  4.34   8.16  ...  .314
# 1    2021  15  815   28.7  4.46  2428  37.46  33.20  4.46   8.04  ...  .318
# 2    2020  15  327   28.4  4.71   898  36.97  32.74  4.71   8.07  ...  .325
# 3    2019  15  727   28.2  4.78  2430  38.37  34.20  4.78   8.59  ...  .323
# 4    2018  15  730   27.9  4.37  2432  38.19  34.01  4.37   8.39  ...  .318
# ..    ...  ..  ...    ...   ...   ...    ...    ...   ...    ...  ...   ...
# 147  1880   8  127   24.8  4.69   680  36.83  35.74  4.69   8.74  ...  .267
# 148  1879   8  119   24.7  5.31   642  38.42  37.62  5.31   9.61  ...  .271
# 149  1878   6   77   24.7  5.17   368  38.07  37.08  5.17   9.62  ...  .279
# 150  1877   6   92   25.9  5.67   360  38.92  37.96  5.67  10.29  ...  .289
# 151  1876   8  121   25.3  5.90   520  39.34  38.69  5.90  10.27  ...  .277
#
# ...

# %%
df=df[0]

# %%
df.shape
# Out:
# (152, 30)

# %%
df.columns
# Out:
# Index(['Year', 'Tms', '#Bat', 'BatAge', 'R/G', 'G', 'PA', 'AB', 'R', 'H', '1B',
#        '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG',
#        'OPS', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB', 'BIP'],
#       dtype='object')

# %%
df.to_csv('BNA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DAED-C6C1
#
#  Directory of C:\Users\ASUS\iNeuron.ai.practice Recorded\pandas
#
# 03/14/2023  11:00 AM    <DIR>          .
# 03/07/2023  12:57 PM    <DIR>          ..
# 03/14/2023  10:04 AM    <DIR>          .ipynb_checkpoints
# 03/08/2023  12:20 PM             1,173 addresses.csv
# 03/15/2023  08:30 AM            21,847 BNA.csv
# 03/08/2023  12:20 PM             1,589 contacts.csv
# 03/08/2023  12:20 PM               277 holiday_schedules.csv
# 03/08/2023  12:20 PM            18,015 locations.csv
# 03/14/2023  09:29 AM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 03/14/2023  09:29 AM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 03/14/2023  09:29 AM            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 03/14/2023  09:29 AM            84,319 LUSID Excel - Manage Orders.xlsx
# ...

# %% [markdown]
# # working with json data

# %%
d="""{"name":"Devendra singh",
"email":"singhdev@gmail.com",
"tech":["ML","DL","NLP"],
"plateform":["techneuron","kidsneuron","ineuron"]
}"""

# %%
import json
import pandas as pd

# %%
result=json.loads(d)

# %%
type(d)
# Out:
# str

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#              name               email tech   plateform
# 0  Devendra singh  singhdev@gmail.com   ML  techneuron
# 1  Devendra singh  singhdev@gmail.com   DL  kidsneuron
# 2  Devendra singh  singhdev@gmail.com  NLP     ineuron

# %%
pd.read_json('{"name":"Devendra singh","email":"singhdev@gmail.com","tech":["ML","DL","NLP"],"plateform":["techneuron","kidsneuron","ineuron"]}')
# Out:
#              name               email tech   plateform
# 0  Devendra singh  singhdev@gmail.com   ML  techneuron
# 1  Devendra singh  singhdev@gmail.com   DL  kidsneuron
# 2  Devendra singh  singhdev@gmail.com  NLP     ineuron

# %%
result['name']
# Out:
# 'Devendra singh'

# %%
import requests

# %%
url='https://c.go-mpulse.net/api/config.json?key=RF6LV-Y7HBS-S5S4P-HB5LE-V8XXL&d=www.nseindia.com&t=5596170&v=1.720.0&if=&sl=1&si=1b678192-1675-44e8-945b-5ff77a335ce0-rrjlnm&bcn=%2F%2F684d0d48.akstat.io%2F&plugins=AK,ConfigOverride,Continuity,PageParams,IFrameDelay,AutoXHR,SPA,History,Angular,Backbone,Ember,RT,CrossDomain,BW,PaintTiming,NavigationTiming,ResourceTiming,Memory,CACHE_RELOAD,Errors,TPAnalytics,UserTiming,Akamai,Early,EventTiming,LOGN&acao=&ak.ai=509815'

# %%
response=requests.get(url)

# %%
response.json()
# Out:
# {'h.key': 'RF6LV-Y7HBS-S5S4P-HB5LE-V8XXL',
#  'h.d': 'nseindia.com',
#  'h.t': 1678861748009,
#  'h.cr': '0cebccd7416883152cbd5b913f733c6faf7e62ac-2f3e6357-732e05c3',
#  'session_id': 'fd57406f-f15f-4559-8ba9-a685b94dd1ec',
#  'site_domain': 'nseindia.com',
#  'beacon_url': '//684d0d46.akstat.io/',
#  'autorun': False,
#  'strip_query_string': True,
#  'beacon_interval': 60,
#  'BW': {'enabled': False},
#  'RT': {'session_exp': 1800},
#  'ResourceTiming': {'enabled': True, 'splitAtPath': True},
#  'History': {'enabled': True, 'auto': True},
#  'Errors': {'enabled': True,
#   'monitorTimeout': False,
#   'monitorEvents': False,
#   'maxErrors': 25,
#   'sendInterval': 250},
#  'Continuity': {'enabled': True},
#  'PageParams': {'xhr': 'none',
#   'pageGroups': [{'type': 'Regexp',
#     'parameter1': '/corporates/corporateHome.html',
#     'parameter2': 'Corporates',
#     'on': ['navigation']},
#    {'type': 'Custom', 'parameter1': 'page[0]', 'on': ['navigation']},
# ...

# %%
pd.DataFrame(response.json()['Akamai'],index=[0,1])
# Out:
#    enabled  dns_prefetch_enabled
# 0     True                  True
# 1     True                  True

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data=response.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51982',
#   'id': 1624807432,
#   'node_id': 'PR_kwDOAA0YD85MEXxr',
#   'number': 51982,
#   'title': 'integer array creation test GH#31104',
#   'user': {'login': 'liang3zy22',
#    'id': 35164941,
#    'node_id': 'MDQ6VXNlcjM1MTY0OTQx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35164941?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liang3zy22',
#    'html_url': 'https://github.com/liang3zy22',
#    'followers_url': 'https://api.github.com/users/liang3zy22/followers',
# ...

# %%
len(data)
# Out:
# 30

# %%
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51982/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/51982',
#  'id': 1624807432,
#  'node_id': 'PR_kwDOAA0YD85MEXxr',
#  'number': 51982,
#  'title': 'integer array creation test GH#31104',
#  'user': {'login': 'liang3zy22',
#   'id': 35164941,
#   'node_id': 'MDQ6VXNlcjM1MTY0OTQx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/35164941?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/liang3zy22',
#   'html_url': 'https://github.com/liang3zy22',
#   'followers_url': 'https://api.github.com/users/liang3zy22/followers',
# ...

# %%
for i in range(len(data)):
    print(data[i]['user']['id'])
# Out:
# 35164941
# 2395780
# 38412262
# 26364415
# 8078968
# 26364415
# 61934744
# 82477528
# 61934744
# 8078968
# 39696536
# 47963215
# 38412262
# 8078968
# 8078968
# 15380498
# 61934744
# 20811121
# 77875500
# 38412262
# 45562402
# 53919701
# 61934744
# 124939984
# 1020496
# 9269985
# 14967061
# 11656932
# 26364415
# 91160475

# %%
df1=pd.DataFrame(data)
df1.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           html_url          id  \
# 0  https://github.com/pandas-dev/pandas/pull/51982  1624807432
# ...

# %%
pd.DataFrame(data[0]['user'],index=range(18)).to_csv('dev.csv')

# %%
df2=pd.read_csv('dev.csv')
df2.head(3)
# Out:
#    Unnamed: 0       login        id               node_id  \
# 0           0  liang3zy22  35164941  MDQ6VXNlcjM1MTY0OTQx
# 1           1  liang3zy22  35164941  MDQ6VXNlcjM1MTY0OTQx
# 2           2  liang3zy22  35164941  MDQ6VXNlcjM1MTY0OTQx
#
#                                           avatar_url  gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/351649...          NaN
# 1  https://avatars.githubusercontent.com/u/351649...          NaN
# 2  https://avatars.githubusercontent.com/u/351649...          NaN
#
#                                        url                       html_url  \
# 0  https://api.github.com/users/liang3zy22  https://github.com/liang3zy22
# 1  https://api.github.com/users/liang3zy22  https://github.com/liang3zy22
# 2  https://api.github.com/users/liang3zy22  https://github.com/liang3zy22
#
#                                        followers_url  \
# 0  https://api.github.com/users/liang3zy22/followers
# 1  https://api.github.com/users/liang3zy22/followers
# ...
